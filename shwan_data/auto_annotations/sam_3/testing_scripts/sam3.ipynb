# %%
pwd
# Out:
# '/home/ubuntu/additional_drive/shwan_data/auto_annotations/sam_3/testing_scripts'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import torch
#       2 from PIL import Image
# ----> 3 from sam3.sam3.model_builder import build_sam3_image_model
#       4 from sam3.sam3.model.sam3_image_processor import Sam3Processor
#
# File ~/additional_drive/shwan_data/auto_annotations/sam_3/testing_scripts/sam3/sam3/__init__.py:3
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates. All Rights Reserved
# ----> 3 from .model_builder import build_sam3_image_model
#       5 __version__ = "0.1.0"
#       7 __all__ = ["build_sam3_image_model"]
#
# File ~/additional_drive/shwan_data/auto_annotations/sam_3/testing_scripts/sam3/sam3/model_builder.py:10
#       8 from huggingface_hub import hf_hub_download
#       9 from iopath.common.file_io import g_pathmgr
# ---> 10 from sam3.model.decoder import (
#      11     TransformerDecoder,
# ...
