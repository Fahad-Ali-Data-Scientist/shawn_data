/ubuntu/additional_drive/shwan_data/yolo_training/runs/train/yolov11l_merged_new/weights/best.pt'
# MODEL_PATH = '/home/ubuntu/Annotations/training/runs/train/yolov11l_merged_new2/weights/best.pt'  
# TRACKER_CFG = str(ROOT / "cfg/trackers/bytetrack.yaml")
CONF_THRESHOLD = 0.25
IOU_THRESHOLD = 0.45
IMGSZ = 640
DEVICE = "0"

UPLOAD_FOLDER = 'uploads'
OUTPUT_FOLDER = 'outputs'
EXPORT_FOLDER = 'exports'
os.makedirs(UPLOAD_FOLDER, exist_ok=True)
os.makedirs(OUTPUT_FOLDER, exist_ok=True)
os.makedirs(EXPORT_FOLDER, exist_ok=True)

print(f"Loading YOLO model from: {MODEL_PATH}")
model = YOLO(MODEL_PATH)
print("Model loaded successfully!")
# Out:
# Loading YOLO model from: /home/ubuntu/additional_drive/shwan_data/yolo_training/runs/train/yolov11l_merged_new/weights/best.pt
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[10], line 17
#      14 os.makedirs(EXPORT_FOLDER, exist_ok=True)
#      16 print(f"Loading YOLO model from: {MODEL_PATH}")
# ---> 17 model = YOLO(MODEL_PATH)
#      18 print("Model loaded successfully!")
#
# File ~/additional_drive/venv/lib/python3.10/site-packages/ultralytics/engine/model.py:95, in Model.__init__(self, model, task)
#      93     self._new(model, task)
#      94 else:
# ---> 95     self._load(model, task)
#      97 self.model_name = model
#
# File ~/additional_drive/venv/lib/python3.10/site-packages/ultralytics/engine/model.py:161, in Model._load(self, weights, task)
#     159 suffix = Path(weights).suffix
#     160 if suffix == ".pt":
# ...

# %%
import torch
import ultralytics.nn.tasks as tasks
from ultralytics import YOLO

with torch.serialization.safe_globals([tasks.DetectionModel]):
    model = YOLO("/home/ubuntu/additional_drive/shwan_data/yolo_training/runs/train/yolov11l_merged_new/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[11], line 6
#       3 from ultralytics import YOLO
#       5 with torch.serialization.safe_globals([tasks.DetectionModel]):
# ----> 6     model = YOLO("/home/ubuntu/additional_drive/shwan_data/yolo_training/runs/train/yolov11l_merged_new/weights/best.pt")
#
# File ~/additional_drive/venv/lib/python3.10/site-packages/ultralytics/engine/model.py:95, in Model.__init__(self, model, task)
#      93     self._new(model, task)
#      94 else:
# ---> 95     self._load(model, task)
#      97 self.model_name = model
#
# File ~/additional_drive/venv/lib/python3.10/site-packages/ultralytics/engine/model.py:161, in Model._load(self, weights, task)
#     159 suffix = Path(weights).suffix
#     160 if suffix == ".pt":
# --> 161     self.model, self.ckpt = attempt_load_one_weight(weights)
#     162     self.task = self.model.args["task"]
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.220 🚀 Python-3.10.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX A4000, 15091MiB)
# Setup complete ✅ (4 CPUs, 20.5 GB RAM, 12.8/96.7 GB disk)

# %%
from ultralytics import YOLO
import os

# %%
MODEL_PATH = '/home/ubuntu/additional_drive/shwan_data/yolo_training/runs/train/yolov11l_merged_new/weights/best.pt'
# MODEL_PATH = '/home/ubuntu/Annotations/training/runs/train/yolov11l_merged_new2/weights/best.pt'  
# TRACKER_CFG = str(ROOT / "cfg/trackers/bytetrack.yaml")
CONF_THRESHOLD = 0.25
IOU_THRESHOLD = 0.45
IMGSZ = 640
DEVICE = "0"

UPLOAD_FOLDER = 'uploads'
OUTPUT_FOLDER = 'outputs'
EXPORT_FOLDER = 'exports'
os.makedirs(UPLOAD_FOLDER, exist_ok=True)
os.makedirs(OUTPUT_FOLDER, exist_ok=True)
os.makedirs(EXPORT_FOLDER, exist_ok=True)

print(f"Loading YOLO model from: {MODEL_PATH}")
model = YOLO(MODEL_PATH)
print("Model loaded successfully!")
# Out:
# Loading YOLO model from: /home/ubuntu/additional_drive/shwan_data/yolo_training/runs/train/yolov11l_merged_new/weights/best.pt
# Model loaded successfully!
